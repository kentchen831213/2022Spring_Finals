# %% [markdown]
# ### Vaccination efficacy data converting
# #### We tried to convert the original graphical table into a usable CSV in our simualtion
# #### Source:
# https://www.healthdata.org/covid/covid-19-vaccine-efficacy-summary

# %%
import pandas as pd

# %%
vac_data = {
            "Vaccine": ["AstraZeneca", "CanSino", "CoronaVac", "Covaxin",
                        "Johnson & Johnson", "Moderna", "Novavax", "Pfizer/BioNTech",
                        "Sinopharm", "Sputnik-V", "Other vaccines", "Other vaccines (MRNA)"],
            "Ancestral_SD": [0.94, 0.66, 0.5, 0.78, 0.86, 0.97, 0.89, 0.95, 0.73, 0.92, 0.75, 0.91],
            "Ancestral_IN": [0.63, 0.62, 0.47, 0.73, 0.72, 0.92, 0.83, 0.86, 0.68, 0.86, 0.7, 0.86],
            "Alpha_SD": [0.94, 0.66, 0.5, 0.78, 0.86, 0.97, 0.89, 0.95, 0.73, 0.92, 0.75, 0.91],
            "Alpha_IN": [0.63, 0.62, 0.47, 0.73, 0.72, 0.92, 0.83, 0.86, 0.68, 0.86, 0.7, 0.86],
            "Beta_SD": [0.94, 0.64, 0.49, 0.76, 0.76, 0.97, 0.86, 0.95, 0.71, 0.89, 0.73, 0.88],
            "Beta_IN": [0.69, 0.61, 0.46, 0.72, 0.64, 0.91, 0.82, 0.84, 0.67, 0.85, 0.69, 0.85],
            "Gamma_SD": [0.94, 0.64, 0.49, 0.76, 0.76, 0.97, 0.86, 0.95, 0.71, 0.89, 0.73, 0.88],
            "Gamma_IN": [0.69, 0.61, 0.46, 0.72, 0.64, 0.91, 0.82, 0.84, 0.67, 0.85, 0.69, 0.85],
            "Delta_SD": [0.94, 0.64, 0.49, 0.76, 0.76, 0.97, 0.86, 0.95, 0.71, 0.89, 0.73, 0.88],
            "Delta_IN": [0.69, 0.61, 0.46, 0.72, 0.64, 0.91, 0.82, 0.84, 0.67, 0.85, 0.69, 0.85],
            "Omicron_SD": [0.71, 0.48, 0.37, 0.57, 0.57, 0.73, 0.65, 0.72, 0.53, 0.67, 0.55, 0.67],
            "Omicron_IN": [0.36, 0.32, 0.24, 0.38, 0.33, 0.48, 0.43, 0.44, 0.35, 0.44, 0.36, 0.45]
            }

# %%
vaccine = pd.DataFrame(vac_data)

# %%
vaccine
# Out:
#                   Vaccine  Ancestral_SD  Ancestral_IN  Alpha_SD  Alpha_IN  \
# 0             AstraZeneca          0.94          0.63      0.94      0.63
# 1                 CanSino          0.66          0.62      0.66      0.62
# 2               CoronaVac          0.50          0.47      0.50      0.47
# 3                 Covaxin          0.78          0.73      0.78      0.73
# 4       Johnson & Johnson          0.86          0.72      0.86      0.72
# 5                 Moderna          0.97          0.92      0.97      0.92
# 6                 Novavax          0.89          0.83      0.89      0.83
# 7         Pfizer/BioNTech          0.95          0.86      0.95      0.86
# 8               Sinopharm          0.73          0.68      0.73      0.68
# 9               Sputnik-V          0.92          0.86      0.92      0.86
# 10         Other vaccines          0.75          0.70      0.75      0.70
# 11  Other vaccines (MRNA)          0.91          0.86      0.91      0.86
#
# ...

# %% [markdown]
# #### Export pandas dataframe into .csv file
# Source: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %%
vaccine.to_csv("vaccine.csv", index=False, encoding="utf-8")
